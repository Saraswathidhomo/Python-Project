# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Campaign data.csv')

# %%
df
# Out:
#               Date Data source               Campaign    Media Type  \
# 0       12/30/2019   Pinterest       Kicks campaign 2       Display
# 1       12/30/2019   Pinterest       Kicks campaign 2       Display
# 2       12/30/2019   Pinterest       Kicks campaign 2       Display
# 3       12/30/2019   Pinterest       Kicks campaign 2       Display
# 4       12/30/2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 0               Colorado Springs-Pueblo  Impressions      1.00
# ...

# %%
df.shape
# Out:
# (123699, 7)

# %%
df.columns
# Out:
# Index(['Date', 'Data source', 'Campaign', 'Media Type', 'City', 'Metric',
#        'Value'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date Data source          Campaign Media Type  \
# 0  12/30/2019   Pinterest  Kicks campaign 2    Display
# 1  12/30/2019   Pinterest  Kicks campaign 2    Display
# 2  12/30/2019   Pinterest  Kicks campaign 2    Display
# 3  12/30/2019   Pinterest  Kicks campaign 2    Display
# 4  12/30/2019   Pinterest  Kicks campaign 2    Display
#
#                        City       Metric  Value
# 0   Colorado Springs-Pueblo  Impressions    1.0
# 1   Colorado Springs-Pueblo   Media Cost    0.0
# 2   Colorado Springs-Pueblo       Clicks    0.0
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0
# 4  Sacramnto-Stkton-Modesto   Media Cost    0.0

# %%
df.tail()
# Out:
#              Date Data source               Campaign    Media Type  \
# 123694  9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695  9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696  9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697  9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698  9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 123694  Sacramento - Stockton - Modesto   Media Cost    136.94
# 123695  Sacramento - Stockton - Modesto       Clicks     81.00
# 123696               Dallas - Ft. Worth  Impressions  16579.00
# 123697               Dallas - Ft. Worth   Media Cost    297.78
# 123698               Dallas - Ft. Worth       Clicks    128.00

# %%
df.iloc()

# %%
df1=pd.DataFrame(data=df,columns=['Date'])

# %%
df1
# Out:
#               Date
# 0       12/30/2019
# 1       12/30/2019
# 2       12/30/2019
# 3       12/30/2019
# 4       12/30/2019
# ...            ...
# 123694   9/30/2021
# 123695   9/30/2021
# 123696   9/30/2021
# 123697   9/30/2021
# 123698   9/30/2021
#
# [123699 rows x 1 columns]

# %%
df.dtypes
# Out:
# Date            object
# Data source     object
# Campaign        object
# Media Type      object
# City            object
# Metric          object
# Value          float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date           0
# Data source    0
# Campaign       0
# Media Type     0
# City           0
# Metric         0
# Value          0
# dtype: int64

# %%
df
# Out:
#               Date Data source               Campaign    Media Type  \
# 0       12/30/2019   Pinterest       Kicks campaign 2       Display
# 1       12/30/2019   Pinterest       Kicks campaign 2       Display
# 2       12/30/2019   Pinterest       Kicks campaign 2       Display
# 3       12/30/2019   Pinterest       Kicks campaign 2       Display
# 4       12/30/2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 0               Colorado Springs-Pueblo  Impressions      1.00
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Data source', 'Campaign', 'Media Type', 'City', 'Metric',
#        'Value'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Date             332
# Data source        2
# Campaign          58
# Media Type         2
# City             263
# Metric             3
# Value          43408
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#              Date Data source      Campaign Media Type  \
# 80807   3/29/2021   Pinterest  shop at home    Display
# 80858   3/29/2021   Pinterest  shop at home    Display
# 80907   3/29/2021   Pinterest  shop at home    Display
# 80908   3/29/2021   Pinterest  shop at home    Display
# 80909   3/29/2021   Pinterest  shop at home    Display
# ...           ...         ...           ...        ...
# 122584  9/27/2021   Pinterest  shop at home    Display
# 122585  9/27/2021   Pinterest  shop at home    Display
# 122586  9/27/2021   Pinterest  shop at home    Display
# 122587  9/27/2021   Pinterest  shop at home    Display
# 122588  9/27/2021   Pinterest  shop at home    Display
#
#                               City       Metric   Value
# 80807                        Utica       Clicks    3.00
# 80858                        Utica       Clicks    3.00
# 80907                        Utica  Impressions  750.00
# 80908                        Utica   Media Cost    5.33
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Data source, Campaign, Media Type, City, Metric, Value]
# Index: []

# %%
df.shape
# Out:
# (122629, 7)

# %%
df.describe()
# Out:
#               Value
# count  1.226290e+05
# mean   6.999154e+03
# std    3.411575e+04
# min    0.000000e+00
# 25%    6.340000e+00
# 50%    7.600000e+01
# 75%    1.156000e+03
# max    1.627800e+06

# %%
df.sort_values
# Out:
# <bound method DataFrame.sort_values of               Date Data source               Campaign    Media Type  \
# 0       12/30/2019   Pinterest       Kicks campaign 2       Display
# 1       12/30/2019   Pinterest       Kicks campaign 2       Display
# 2       12/30/2019   Pinterest       Kicks campaign 2       Display
# 3       12/30/2019   Pinterest       Kicks campaign 2       Display
# 4       12/30/2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# ...

# %%
df.sample()
# Out:
#            Date Data source           Campaign Media Type     City  \
# 81603  4/5/2021   Pinterest  Armada campaign 2    Display  Houston
#
#             Metric  Value
# 81603  Impressions    9.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 122629 entries, 0 to 123698
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Date         122629 non-null  object
#  1   Data source  122629 non-null  object
#  2   Campaign     122629 non-null  object
#  3   Media Type   122629 non-null  object
#  4   City         122629 non-null  object
#  5   Metric       122629 non-null  object
#  6   Value        122629 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 7.5+ MB

# %%
df.describe(include='all')
# Out:
#              Date Data source           Campaign    Media Type      City  \
# count      122629      122629             122629        122629    122629
# unique        332           2                 58             2       263
# top     9/27/2021   Pinterest  Armada campaign 2  Online Video  New York
# freq         3813       65875              13392         99363      3483
# mean          NaN         NaN                NaN           NaN       NaN
# std           NaN         NaN                NaN           NaN       NaN
# min           NaN         NaN                NaN           NaN       NaN
# 25%           NaN         NaN                NaN           NaN       NaN
# 50%           NaN         NaN                NaN           NaN       NaN
# 75%           NaN         NaN                NaN           NaN       NaN
# max           NaN         NaN                NaN           NaN       NaN
#
#              Metric         Value
# count        122629  1.226290e+05
# ...

# %%
df.loc[:,'City']
# Out:
# 0                 Colorado Springs-Pueblo
# 1                 Colorado Springs-Pueblo
# 2                 Colorado Springs-Pueblo
# 3                Sacramnto-Stkton-Modesto
# 4                Sacramnto-Stkton-Modesto
#                        ...
# 123694    Sacramento - Stockton - Modesto
# 123695    Sacramento - Stockton - Modesto
# 123696                 Dallas - Ft. Worth
# 123697                 Dallas - Ft. Worth
# 123698                 Dallas - Ft. Worth
# Name: City, Length: 122629, dtype: object

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#               Date Data source               Campaign    Media Type  \
# 0       12/30/2019   Pinterest       Kicks campaign 2       Display
# 1       12/30/2019   Pinterest       Kicks campaign 2       Display
# 2       12/30/2019   Pinterest       Kicks campaign 2       Display
# 3       12/30/2019   Pinterest       Kicks campaign 2       Display
# 4       12/30/2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698   9/30/2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 0               Colorado Springs-Pueblo  Impressions      1.00
# ...

# %%
#nsmallest - return the first n rows ordered by columns in ascending order
#nlargest - return the first n rows ordered by columns in descending order

# %% [markdown]
# Find out the top 5 months in terms of impression

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date           datetime64[ns]
# Data source            object
# Campaign               object
# Media Type             object
# City                   object
# Metric                 object
# Value                 float64
# dtype: object

# %%
df.head()
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 1 2019-12-30   Pinterest  Kicks campaign 2    Display
# 2 2019-12-30   Pinterest  Kicks campaign 2    Display
# 3 2019-12-30   Pinterest  Kicks campaign 2    Display
# 4 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                        City       Metric  Value
# 0   Colorado Springs-Pueblo  Impressions    1.0
# 1   Colorado Springs-Pueblo   Media Cost    0.0
# 2   Colorado Springs-Pueblo       Clicks    0.0
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0
# 4  Sacramnto-Stkton-Modesto   Media Cost    0.0

# %%
df['Day']=df['Date'].dt.day
df['Month']=df['Date'].dt.month
df['Year']=df['Date'].dt.year

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
df_imp=df[df['Metric']=='Impressions']

# %%
df_imp
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
(df_imp.groupby('Month')['Value'].sum()).sort_values(ascending=False)[:5]
# Out:
# Month
# 9     195438538.0
# 3     159488182.0
# 10    129386691.0
# 8     117299533.0
# 2      95672149.0
# Name: Value, dtype: float64

# %%
(df.groupby(['Month','Metric','Year'])['Value'].sum()).sort_values(ascending=False).reset_index()
# Out:
#     Month       Metric  Year        Value
# 0       9  Impressions  2021  165961494.0
# 1      10  Impressions  2020  129386691.0
# 2       8  Impressions  2021  110579025.0
# 3       3  Impressions  2021  101719848.0
# 4       2  Impressions  2020   61351689.0
# ..    ...          ...   ...          ...
# 61      4   Media Cost  2020          0.0
# 62      5   Media Cost  2020          0.0
# 63      5   Media Cost  2021          0.0
# 64      6   Media Cost  2021          0.0
# 65      1       Clicks  2020          0.0
#
# [66 rows x 4 columns]

# %%
large5=df.nlargest(5,'Value')

# %%
large5
# Out:
#              Date Data source               Campaign Media Type         City  \
# 110946 2021-09-13   Pinterest  Pathfinder campaign 1    Display  Los Angeles
# 3936   2020-03-09   Pinterest      Armada campaign 2    Display  Los Angeles
# 115773 2021-09-20   Pinterest  Pathfinder campaign 1    Display  Los Angeles
# 3279   2020-03-02   Pinterest      Armada campaign 2    Display  Los Angeles
# 2703   2020-03-02   Pinterest      Armada campaign 2    Display     New York
#
#              Metric      Value  Day  Month  Year
# 110946  Impressions  1627800.0   13      9  2021
# 3936    Impressions  1483786.0    9      3  2020
# 115773  Impressions  1366794.0   20      9  2021
# 3279    Impressions  1331403.0    2      3  2020
# 2703    Impressions  1323275.0    2      3  2020

# %%
df['Value'].nlargest(n=5)
# Out:
# 110946    1627800.0
# 3936      1483786.0
# 115773    1366794.0
# 3279      1331403.0
# 2703      1323275.0
# Name: Value, dtype: float64

# %%
df.groupby('Date')['Value'].nlargest(5)
# Out:
# Date
# 2019-12-30  18            5.0
#             15            3.0
#             6             2.0
#             12            2.0
#             0             1.0
#                        ...
# 2021-09-30  123564    72080.0
#             123600    55909.0
#             123597    44954.0
#             123576    43478.0
#             123612    35335.0
# Name: Value, Length: 1660, dtype: float64

# %%
large5=df.nlargest(5,'Value')['Metric']

# %%
large5
# Out:
# 110946    Impressions
# 3936      Impressions
# 115773    Impressions
# 3279      Impressions
# 2703      Impressions
# Name: Metric, dtype: object

# %%
df.groupby('Metric')['Value'].nlargest(5)
# Out:
# Metric
# Clicks       3938         2879.00
#              1409         2749.00
#              2705         2692.00
#              2630         2640.00
#              3281         2634.00
# Impressions  110946    1627800.00
#              3936      1483786.00
#              115773    1366794.00
#              3279      1331403.00
#              2703      1323275.00
# Media Cost   35167       15365.90
#              30283       15111.60
#              25663       14072.47
#              35170       12059.50
#              30286       11975.97
# Name: Value, dtype: float64

# %% [markdown]
# Find out the top 5 months in terms of impression

# %%
df_c=df[df['Metric']=='Impressions']

# %%
df_c
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
large5=df_c.nlargest(5,'Value')['Date']

# %%
large5
# Out:
# 110946   2021-09-13
# 3936     2020-03-09
# 115773   2021-09-20
# 3279     2020-03-02
# 2703     2020-03-02
# Name: Date, dtype: datetime64[ns]

# %%
df_c['Date']=pd.to_datetime(df_c['Date'])

# %%
df_c
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
large5=df_c.nlargest(5,'Value')['Date']

# %%
large5
# Out:
# 110946   2021-09-13
# 3936     2020-03-09
# 115773   2021-09-20
# 3279     2020-03-02
# 2703     2020-03-02
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# Which model has maximum impressions?

# %%
ds=pd.read_csv('Campaign datas.csv')

# %%
ds
# Out:
#                  Campaign   Message type        Model
# 0       Sentra campaign 2  Future Market       Sentra
# 1       Sentra campaign 4  Future Market       Sentra
# 2       Sentra campaign 3  Future Market       Sentra
# 3       Sentra campaign 1  Future Market       Sentra
# 4       Altima campaign 1  Future Market       Altima
# 5       Altima campaign 5  Future Market       Altima
# 6       Altima campaign 4  Future Market       Altima
# 7       Altima campaign 6  Future Market       Altima
# 8        Kicks campaign 6  Future Market        Kicks
# 9        Kicks campaign 5  Future Market        Kicks
# 10       Rogue campaign 1  Future Market        Rogue
# 11       Rogue campaign 3  Future Market        Rogue
# 12       Rogue pre launch  Future Market        Rogue
# 13       Rogue campaign 5  Future Market        Rogue
# 14       Rogue campaign 4  Future Market        Rogue
# 15  Pathfinder campaign 3    Near Market   Pathfinder
# ...

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
df_m=pd.merge(df,ds,on='Campaign')

# %%
df_m
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
df_m.head(3)
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 1 2019-12-30   Pinterest  Kicks campaign 2    Display
# 2 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                       City       Metric  Value  Day  Month  Year Message type  \
# 0  Colorado Springs-Pueblo  Impressions    1.0   30     12  2019  Near Market
# 1  Colorado Springs-Pueblo   Media Cost    0.0   30     12  2019  Near Market
# 2  Colorado Springs-Pueblo       Clicks    0.0   30     12  2019  Near Market
#
#    Model
# 0  Kicks
# 1  Kicks
# 2  Kicks

# %%
df_m.max()
# Out:
# Date            2021-09-30 00:00:00
# Data source                Snapchat
# Campaign               shop at home
# Media Type             Online Video
# City                     Zanesville
# Metric                   Media Cost
# Value                     1627800.0
# Day                              31
# Month                            12
# Year                           2021
# Message type            Near Market
# Model                        Sentra
# dtype: object

# %%
df_m[df_m['Metric'] == 'Impressions']
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 122614 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122617 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122620 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122623 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
(df_m.groupby('Model')['Value'].sum()).sort_values(ascending=False)[:3]
# Out:
# Model
# Pathfinder    2.793421e+08
# Armada        1.770488e+08
# Rogue         1.339567e+08
# Name: Value, dtype: float64

# %% [markdown]
# Find out the top 3 campaigns in terms of impressions for every message type

# %%
df_m
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
(df_m.groupby(['Message type','Campaign'])['Value'].sum()).sort_values(ascending=False).reset_index()
# Out:
#      Message type               Campaign         Value
# 0     Near Market      Armada campaign 2  1.197572e+08
# 1     Near Market  Pathfinder campaign 2  1.160629e+08
# 2     Near Market  Pathfinder campaign 6  5.285515e+07
# 3     Near Market  Pathfinder campaign 1  4.921421e+07
# 4   Future Market      Altima campaign 3  4.584127e+07
# 5     Near Market      Armada campaign 4  3.782937e+07
# 6   Future Market      Altima campaign 1  3.650185e+07
# 7   Future Market       Kicks campaign 4  3.387167e+07
# 8   Future Market       Rogue campaign 5  3.379682e+07
# 9   Future Market       Kicks campaign 6  3.353479e+07
# 10  Future Market       Rogue campaign 4  3.320477e+07
# 11  Future Market       Kicks campaign 3  2.740015e+07
# 12  Future Market       Rogue campaign 2  2.590745e+07
# 13  Future Market       Rogue campaign 1  1.921213e+07
# 14    Near Market  Pathfinder campaign 5  1.771970e+07
# 15    Near Market      Armada campaign 3  1.765449e+07
# ...

# %% [markdown]
# 4.Does the campaign with maximum impressions also have maximum clicks?

# %%
dp=df[df['Metric']=='Clicks']

# %%
dp
# Out:
#              Date Data source               Campaign    Media Type  \
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 5      2019-12-30   Pinterest       Kicks campaign 2       Display
# 8      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 11     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 14     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123686 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123689 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123692 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City  Metric  Value  Day  Month  Year
# 2               Colorado Springs-Pueblo  Clicks    0.0   30     12  2019
# ...

# %%
db=df[df['Metric']=='Impressions']

# %%
db
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
dp1=dp.groupby(['Campaign','Metric'])['Value'].sum().reset_index()

# %%
dp1
# Out:
#                  Campaign  Metric     Value
# 0       Altima campaign 1  Clicks  148715.0
# 1       Altima campaign 2  Clicks    2795.0
# 2       Altima campaign 3  Clicks   13412.0
# 3       Altima campaign 4  Clicks    3968.0
# 4       Altima campaign 5  Clicks   13400.0
# 5       Altima campaign 6  Clicks    7732.0
# 6       Altima campaign 7  Clicks     672.0
# 7       Altima campaign 8  Clicks    1790.0
# 8       Armada campaign 1  Clicks       0.0
# 9       Armada campaign 2  Clicks  241938.0
# 10      Armada campaign 3  Clicks   27401.0
# 11      Armada campaign 4  Clicks   59462.0
# 12       Kicks campaign 1  Clicks      25.0
# 13       Kicks campaign 2  Clicks       7.0
# 14       Kicks campaign 3  Clicks   52065.0
# 15       Kicks campaign 4  Clicks   25146.0
# 16       Kicks campaign 5  Clicks   12584.0
# 17       Kicks campaign 6  Clicks  170446.0
# 18  Pathfinder campaign 1  Clicks   29140.0
# 19  Pathfinder campaign 2  Clicks   86662.0
# ...

# %%
db1=db.groupby(['Campaign','Metric'])['Value'].sum().reset_index()

# %%
db1
# Out:
#                  Campaign       Metric        Value
# 0       Altima campaign 1  Impressions   35863660.0
# 1       Altima campaign 2  Impressions    7200627.0
# 2       Altima campaign 3  Impressions   45451489.0
# 3       Altima campaign 4  Impressions     380995.0
# 4       Altima campaign 5  Impressions    1176593.0
# 5       Altima campaign 6  Impressions    1533773.0
# 6       Altima campaign 7  Impressions    2043425.0
# 7       Altima campaign 8  Impressions    6172814.0
# 8       Armada campaign 1  Impressions    1799471.0
# 9       Armada campaign 2  Impressions  118817195.0
# 10      Armada campaign 3  Impressions   17482050.0
# 11      Armada campaign 4  Impressions   37470993.0
# 12       Kicks campaign 1  Impressions     120791.0
# 13       Kicks campaign 2  Impressions       1485.0
# 14       Kicks campaign 3  Impressions   27167086.0
# 15       Kicks campaign 4  Impressions   33664998.0
# 16       Kicks campaign 5  Impressions    1981485.0
# ...

# %%
dw=pd.merge(dp1,db1, on='Campaign')

# %%
dw
# Out:
#                  Campaign Metric_x   Value_x     Metric_y      Value_y
# 0       Altima campaign 1   Clicks  148715.0  Impressions   35863660.0
# 1       Altima campaign 2   Clicks    2795.0  Impressions    7200627.0
# 2       Altima campaign 3   Clicks   13412.0  Impressions   45451489.0
# 3       Altima campaign 4   Clicks    3968.0  Impressions     380995.0
# 4       Altima campaign 5   Clicks   13400.0  Impressions    1176593.0
# 5       Altima campaign 6   Clicks    7732.0  Impressions    1533773.0
# 6       Altima campaign 7   Clicks     672.0  Impressions    2043425.0
# 7       Altima campaign 8   Clicks    1790.0  Impressions    6172814.0
# 8       Armada campaign 1   Clicks       0.0  Impressions    1799471.0
# 9       Armada campaign 2   Clicks  241938.0  Impressions  118817195.0
# 10      Armada campaign 3   Clicks   27401.0  Impressions   17482050.0
# 11      Armada campaign 4   Clicks   59462.0  Impressions   37470993.0
# ...

# %%
dw.max()
# Out:
# Campaign    shop at home
# Metric_x          Clicks
# Value_x         241938.0
# Metric_y     Impressions
# Value_y      118817195.0
# dtype: object

# %% [markdown]
# 5.	Find out the top 3 campaigns in terms of CPM (CPM stands for cost per mile which means cost per 1000 impressions. CPM = total media cost/total impressions * 1000)

# %%
df_m
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
df_m.head()
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 1 2019-12-30   Pinterest  Kicks campaign 2    Display
# 2 2019-12-30   Pinterest  Kicks campaign 2    Display
# 3 2019-12-30   Pinterest  Kicks campaign 2    Display
# 4 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                        City       Metric  Value  Day  Month  Year  \
# 0   Colorado Springs-Pueblo  Impressions    1.0   30     12  2019
# 1   Colorado Springs-Pueblo   Media Cost    0.0   30     12  2019
# 2   Colorado Springs-Pueblo       Clicks    0.0   30     12  2019
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0   30     12  2019
# 4  Sacramnto-Stkton-Modesto   Media Cost    0.0   30     12  2019
#
#   Message type  Model
# 0  Near Market  Kicks
# 1  Near Market  Kicks
# 2  Near Market  Kicks
# 3  Near Market  Kicks
# 4  Near Market  Kicks

# %%
df_m.tail()
# Out:
#              Date Data source               Campaign    Media Type  \
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 122624  Sacramento - Stockton - Modesto   Media Cost    136.94   30      9
# 122625  Sacramento - Stockton - Modesto       Clicks     81.00   30      9
# 122626               Dallas - Ft. Worth  Impressions  16579.00   30      9
# 122627               Dallas - Ft. Worth   Media Cost    297.78   30      9
# 122628               Dallas - Ft. Worth       Clicks    128.00   30      9
#
#         Year Message type       Model
# 122624  2021  Near Market  Pathfinder
# ...

# %%
df_imp.groupby(['Campaign','Metric'])['Value'].sum()
# Out:
# Campaign               Metric
# Altima campaign 1      Impressions     35863660.0
# Altima campaign 2      Impressions      7200627.0
# Altima campaign 3      Impressions     45451489.0
# Altima campaign 4      Impressions       380995.0
# Altima campaign 5      Impressions      1176593.0
# Altima campaign 6      Impressions      1533773.0
# Altima campaign 7      Impressions      2043425.0
# Altima campaign 8      Impressions      6172814.0
# Armada campaign 1      Impressions      1799471.0
# Armada campaign 2      Impressions    118817195.0
# Armada campaign 3      Impressions     17482050.0
# Armada campaign 4      Impressions     37470993.0
# Kicks campaign 1       Impressions       120791.0
# Kicks campaign 2       Impressions         1485.0
# Kicks campaign 3       Impressions     27167086.0
# Kicks campaign 4       Impressions     33664998.0
# Kicks campaign 5       Impressions      1981485.0
# Kicks campaign 6       Impressions     32993380.0
# ...

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
df3=df[df['Metric']=='Media Cost']

# %%
df3
# Out:
#              Date Data source               Campaign    Media Type  \
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# 7      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 10     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 13     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123685 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123688 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123691 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City      Metric   Value  Day  Month  Year
# 1               Colorado Springs-Pueblo  Media Cost    0.00   30     12  2019
# ...

# %%
df3.groupby(['Campaign','Metric'])['Value'].sum()
# Out:
# Campaign               Metric
# Altima campaign 1      Media Cost    489477.29
# Altima campaign 2      Media Cost     74693.85
# Altima campaign 3      Media Cost    376369.35
# Altima campaign 4      Media Cost      6000.05
# Altima campaign 5      Media Cost     18391.45
# Altima campaign 6      Media Cost     13033.96
# Altima campaign 7      Media Cost     19614.55
# Altima campaign 8      Media Cost     47398.70
# Armada campaign 1      Media Cost      8210.77
# Armada campaign 2      Media Cost    698093.58
# Armada campaign 3      Media Cost    145040.71
# Armada campaign 4      Media Cost    298919.40
# Kicks campaign 1       Media Cost         0.00
# Kicks campaign 2       Media Cost         0.00
# Kicks campaign 3       Media Cost    181003.85
# Kicks campaign 4       Media Cost    181523.37
# Kicks campaign 5       Media Cost     28367.02
# Kicks campaign 6       Media Cost    370962.96
# Pathfinder campaign 1  Media Cost    261944.37
# ...

# %%
df5=df_imp.groupby(['Campaign','Metric'])['Value'].sum().reset_index()

# %%
df3=df[df['Metric']=='Media Cost']

# %%
df5
# Out:
#                  Campaign       Metric        Value
# 0       Altima campaign 1  Impressions   35863660.0
# 1       Altima campaign 2  Impressions    7200627.0
# 2       Altima campaign 3  Impressions   45451489.0
# 3       Altima campaign 4  Impressions     380995.0
# 4       Altima campaign 5  Impressions    1176593.0
# 5       Altima campaign 6  Impressions    1533773.0
# 6       Altima campaign 7  Impressions    2043425.0
# 7       Altima campaign 8  Impressions    6172814.0
# 8       Armada campaign 1  Impressions    1799471.0
# 9       Armada campaign 2  Impressions  118817195.0
# 10      Armada campaign 3  Impressions   17482050.0
# 11      Armada campaign 4  Impressions   37470993.0
# 12       Kicks campaign 1  Impressions     120791.0
# 13       Kicks campaign 2  Impressions       1485.0
# 14       Kicks campaign 3  Impressions   27167086.0
# 15       Kicks campaign 4  Impressions   33664998.0
# 16       Kicks campaign 5  Impressions    1981485.0
# ...

# %%
df6=df3.groupby(['Campaign','Metric'])['Value'].sum().reset_index()

# %%
df6
# Out:
#                  Campaign      Metric      Value
# 0       Altima campaign 1  Media Cost  489477.29
# 1       Altima campaign 2  Media Cost   74693.85
# 2       Altima campaign 3  Media Cost  376369.35
# 3       Altima campaign 4  Media Cost    6000.05
# 4       Altima campaign 5  Media Cost   18391.45
# 5       Altima campaign 6  Media Cost   13033.96
# 6       Altima campaign 7  Media Cost   19614.55
# 7       Altima campaign 8  Media Cost   47398.70
# 8       Armada campaign 1  Media Cost    8210.77
# 9       Armada campaign 2  Media Cost  698093.58
# 10      Armada campaign 3  Media Cost  145040.71
# 11      Armada campaign 4  Media Cost  298919.40
# 12       Kicks campaign 1  Media Cost       0.00
# 13       Kicks campaign 2  Media Cost       0.00
# 14       Kicks campaign 3  Media Cost  181003.85
# 15       Kicks campaign 4  Media Cost  181523.37
# 16       Kicks campaign 5  Media Cost   28367.02
# 17       Kicks campaign 6  Media Cost  370962.96
# ...

# %%
df5.head()
# Out:
#             Campaign       Metric       Value
# 0  Altima campaign 1  Impressions  35863660.0
# 1  Altima campaign 2  Impressions   7200627.0
# 2  Altima campaign 3  Impressions  45451489.0
# 3  Altima campaign 4  Impressions    380995.0
# 4  Altima campaign 5  Impressions   1176593.0

# %%
df6.head()
# Out:
#             Campaign      Metric      Value
# 0  Altima campaign 1  Media Cost  489477.29
# 1  Altima campaign 2  Media Cost   74693.85
# 2  Altima campaign 3  Media Cost  376369.35
# 3  Altima campaign 4  Media Cost    6000.05
# 4  Altima campaign 5  Media Cost   18391.45

# %%
df_p=pd.merge(df5,df6,on='Campaign')

# %%
df_p
# Out:
#                  Campaign     Metric_x      Value_x    Metric_y    Value_y
# 0       Altima campaign 1  Impressions   35863660.0  Media Cost  489477.29
# 1       Altima campaign 2  Impressions    7200627.0  Media Cost   74693.85
# 2       Altima campaign 3  Impressions   45451489.0  Media Cost  376369.35
# 3       Altima campaign 4  Impressions     380995.0  Media Cost    6000.05
# 4       Altima campaign 5  Impressions    1176593.0  Media Cost   18391.45
# 5       Altima campaign 6  Impressions    1533773.0  Media Cost   13033.96
# 6       Altima campaign 7  Impressions    2043425.0  Media Cost   19614.55
# 7       Altima campaign 8  Impressions    6172814.0  Media Cost   47398.70
# 8       Armada campaign 1  Impressions    1799471.0  Media Cost    8210.77
# 9       Armada campaign 2  Impressions  118817195.0  Media Cost  698093.58
# 10      Armada campaign 3  Impressions   17482050.0  Media Cost  145040.71
# ...

# %%
df_p.head(3)
# Out:
#             Campaign     Metric_x     Value_x    Metric_y    Value_y
# 0  Altima campaign 1  Impressions  35863660.0  Media Cost  489477.29
# 1  Altima campaign 2  Impressions   7200627.0  Media Cost   74693.85
# 2  Altima campaign 3  Impressions  45451489.0  Media Cost  376369.35

# %%
df_p['CPM']=(df_p['Value_y']/df_p['Value_x'])*1000

# %%
df_p
# Out:
#                  Campaign     Metric_x      Value_x    Metric_y    Value_y  \
# 0       Altima campaign 1  Impressions   35863660.0  Media Cost  489477.29
# 1       Altima campaign 2  Impressions    7200627.0  Media Cost   74693.85
# 2       Altima campaign 3  Impressions   45451489.0  Media Cost  376369.35
# 3       Altima campaign 4  Impressions     380995.0  Media Cost    6000.05
# 4       Altima campaign 5  Impressions    1176593.0  Media Cost   18391.45
# 5       Altima campaign 6  Impressions    1533773.0  Media Cost   13033.96
# 6       Altima campaign 7  Impressions    2043425.0  Media Cost   19614.55
# 7       Altima campaign 8  Impressions    6172814.0  Media Cost   47398.70
# 8       Armada campaign 1  Impressions    1799471.0  Media Cost    8210.77
# 9       Armada campaign 2  Impressions  118817195.0  Media Cost  698093.58
# 10      Armada campaign 3  Impressions   17482050.0  Media Cost  145040.71
# ...

# %% [markdown]
# 6.	What is the monthly average media cost for different media types?

# %%
df_m
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
df_m1=df_m[df_m['Metric']=='Media Cost']

# %%
df_m1
# Out:
#              Date Data source               Campaign    Media Type  \
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# 7      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 10     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 13     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 122615 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122618 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122621 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City      Metric   Value  Day  Month  Year  \
# 1               Colorado Springs-Pueblo  Media Cost    0.00   30     12  2019
# ...

# %%
(df_m1.groupby(['Month','Metric','Year'])['Value'].mean()).reset_index()
# Out:
#     Month      Metric  Year       Value
# 0       1  Media Cost  2020    0.000000
# 1       1  Media Cost  2021  119.813492
# 2       2  Media Cost  2020  421.122630
# 3       2  Media Cost  2021  151.257794
# 4       3  Media Cost  2020  302.758842
# 5       3  Media Cost  2021  174.675495
# 6       4  Media Cost  2020    0.000000
# 7       4  Media Cost  2021  124.449810
# 8       5  Media Cost  2020    0.000000
# 9       5  Media Cost  2021    0.000000
# 10      6  Media Cost  2020    6.744024
# 11      6  Media Cost  2021    0.000000
# 12      7  Media Cost  2020   24.068340
# 13      7  Media Cost  2021    0.000000
# 14      8  Media Cost  2020   63.770189
# 15      8  Media Cost  2021  242.316774
# 16      9  Media Cost  2020  477.379175
# 17      9  Media Cost  2021  267.725076
# 18     10  Media Cost  2020  240.864445
# 19     11  Media Cost  2020  123.188914
# 20     12  Media Cost  2019    0.000000
# 21     12  Media Cost  2020  217.150739

# %% [markdown]
# 7.	Which media type is more expensive in terms of CPM?

# %%
df_m
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
df_m.head()
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 1 2019-12-30   Pinterest  Kicks campaign 2    Display
# 2 2019-12-30   Pinterest  Kicks campaign 2    Display
# 3 2019-12-30   Pinterest  Kicks campaign 2    Display
# 4 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                        City       Metric  Value  Day  Month  Year  \
# 0   Colorado Springs-Pueblo  Impressions    1.0   30     12  2019
# 1   Colorado Springs-Pueblo   Media Cost    0.0   30     12  2019
# 2   Colorado Springs-Pueblo       Clicks    0.0   30     12  2019
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0   30     12  2019
# 4  Sacramnto-Stkton-Modesto   Media Cost    0.0   30     12  2019
#
#   Message type  Model
# 0  Near Market  Kicks
# 1  Near Market  Kicks
# 2  Near Market  Kicks
# 3  Near Market  Kicks
# 4  Near Market  Kicks

# %%
df_m.tail()
# Out:
#              Date Data source               Campaign    Media Type  \
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 122624  Sacramento - Stockton - Modesto   Media Cost    136.94   30      9
# 122625  Sacramento - Stockton - Modesto       Clicks     81.00   30      9
# 122626               Dallas - Ft. Worth  Impressions  16579.00   30      9
# 122627               Dallas - Ft. Worth   Media Cost    297.78   30      9
# 122628               Dallas - Ft. Worth       Clicks    128.00   30      9
#
#         Year Message type       Model
# 122624  2021  Near Market  Pathfinder
# ...

# %%
dk1=df_m[df_m['Media Type']=='Display']

# %%
dk1
# Out:
#              Date Data source            Campaign Media Type  \
# 0      2019-12-30   Pinterest    Kicks campaign 2    Display
# 1      2019-12-30   Pinterest    Kicks campaign 2    Display
# 2      2019-12-30   Pinterest    Kicks campaign 2    Display
# 3      2019-12-30   Pinterest    Kicks campaign 2    Display
# 4      2019-12-30   Pinterest    Kicks campaign 2    Display
# ...           ...         ...                 ...        ...
# 121535 2021-09-27   Pinterest   Sentra campaign 6    Display
# 121536 2021-09-27   Pinterest   Sentra campaign 6    Display
# 121543 2021-09-27   Pinterest  Sentra campaign 22    Display
# 121544 2021-09-27   Pinterest  Sentra campaign 22    Display
# 121545 2021-09-27   Pinterest  Sentra campaign 22    Display
#
#                              City       Metric  Value  Day  Month  Year  \
# 0         Colorado Springs-Pueblo  Impressions    1.0   30     12  2019
# 1         Colorado Springs-Pueblo   Media Cost    0.0   30     12  2019
# ...

# %%
dk11=dk1.groupby(['Campaign','Media Type'])['Value'].sum().reset_index()

# %%
dk11
# Out:
#                  Campaign Media Type         Value
# 0       Altima campaign 2    Display  1.870000e+02
# 1       Altima campaign 3    Display  7.830000e+02
# 2       Altima campaign 5    Display  2.621000e+01
# 3       Altima campaign 7    Display  2.160000e+02
# 4       Altima campaign 8    Display  2.530000e+02
# 5       Armada campaign 1    Display  1.807682e+06
# 6       Armada campaign 2    Display  1.197572e+08
# 7       Armada campaign 3    Display  2.040000e+02
# 8       Armada campaign 4    Display  2.740000e+02
# 9        Kicks campaign 1    Display  1.430000e+02
# 10       Kicks campaign 2    Display  1.492000e+03
# 11       Kicks campaign 3    Display  2.610000e+02
# 12       Kicks campaign 4    Display  2.710000e+02
# 13       Kicks campaign 6    Display  9.000000e+00
# 14  Pathfinder campaign 1    Display  4.921421e+07
# 15       Rogue campaign 2    Display  2.720000e+02
# 16     Sentra campaign 10    Display  1.600000e+01
# ...

# %%
dk2=df_m[df_m['Media Type']=='Online Video']

# %%
dk2
# Out:
#              Date Data source               Campaign    Media Type  \
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 7      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 8      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 10     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  Month  \
# 6                              New York  Impressions      2.00   30     12
# ...

# %%
dk22=dk2.groupby(['Campaign','Media Type'])['Value'].sum().reset_index()

# %%
dk22
# Out:
#                  Campaign    Media Type         Value
# 0       Altima campaign 1  Online Video  3.650185e+07
# 1       Altima campaign 2  Online Video  7.277929e+06
# 2       Altima campaign 3  Online Video  4.584049e+07
# 3       Altima campaign 4  Online Video  3.909630e+05
# 4       Altima campaign 5  Online Video  1.208358e+06
# 5       Altima campaign 6  Online Video  1.554539e+06
# 6       Altima campaign 7  Online Video  2.063496e+06
# 7       Altima campaign 8  Online Video  6.221750e+06
# 8       Armada campaign 3  Online Video  1.765429e+07
# 9       Armada campaign 4  Online Video  3.782910e+07
# 10       Kicks campaign 1  Online Video  1.206730e+05
# 11       Kicks campaign 3  Online Video  2.739989e+07
# 12       Kicks campaign 4  Online Video  3.387140e+07
# 13       Kicks campaign 5  Online Video  2.022436e+06
# 14       Kicks campaign 6  Online Video  3.353478e+07
# 15  Pathfinder campaign 2  Online Video  1.160629e+08
# ...

# %%
dt=pd.merge(dk11,dk22,on='Campaign')

# %%
dt
# Out:
#               Campaign Media Type_x     Value_x  Media Type_y      Value_y
# 0    Altima campaign 2      Display      187.00  Online Video   7277928.85
# 1    Altima campaign 3      Display      783.00  Online Video  45840487.35
# 2    Altima campaign 5      Display       26.21  Online Video   1208358.24
# 3    Altima campaign 7      Display      216.00  Online Video   2063495.55
# 4    Altima campaign 8      Display      253.00  Online Video   6221749.70
# 5    Armada campaign 3      Display      204.00  Online Video  17654287.71
# 6    Armada campaign 4      Display      274.00  Online Video  37829100.40
# 7     Kicks campaign 1      Display      143.00  Online Video    120673.00
# 8     Kicks campaign 3      Display      261.00  Online Video  27399893.85
# 9     Kicks campaign 4      Display      271.00  Online Video  33871396.37
# 10    Kicks campaign 6      Display        9.00  Online Video  33534779.96
# ...

# %%
dt['CPM']=(dt['Value_y']/dt['Value_x'])*1000

# %%
dt
# Out:
#               Campaign Media Type_x     Value_x  Media Type_y      Value_y  \
# 0    Altima campaign 2      Display      187.00  Online Video   7277928.85
# 1    Altima campaign 3      Display      783.00  Online Video  45840487.35
# 2    Altima campaign 5      Display       26.21  Online Video   1208358.24
# 3    Altima campaign 7      Display      216.00  Online Video   2063495.55
# 4    Altima campaign 8      Display      253.00  Online Video   6221749.70
# 5    Armada campaign 3      Display      204.00  Online Video  17654287.71
# 6    Armada campaign 4      Display      274.00  Online Video  37829100.40
# 7     Kicks campaign 1      Display      143.00  Online Video    120673.00
# 8     Kicks campaign 3      Display      261.00  Online Video  27399893.85
# 9     Kicks campaign 4      Display      271.00  Online Video  33871396.37
# 10    Kicks campaign 6      Display        9.00  Online Video  33534779.96
# ...
